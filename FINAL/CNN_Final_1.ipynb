# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar10

import os
import numpy as np
import matplotlib.pyplot as plt

# ignore information messages from tensorflow, but we will receive error messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %%
# Load CIFAR-10 dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
#images from the dataset
plt.figure(figsize=(20, 8))
for i in range(50):
    plt.subplot(5, 10, i + 1)
    plt.imshow(X_train[i])
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(class_names[Y_train[i][0]])

plt.show()

# %%
# Normalize pixel values to be between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
# Defining a function to create and compile the model
def create_model(optimizer, loss):
    model = keras.Sequential([
        keras.Input(shape=(32, 32, 3)),
        layers.Conv2D(filters=32, kernel_size=(5, 5), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    return model

# Training the model with Adam optimizer and Categorical Cross-Entropy loss
model_adam_categorical = create_model(optimizer='adam', loss='categorical_crossentropy')
history_adam_categorical = model_adam_categorical.fit(X_train, tf.keras.utils.to_categorical(Y_train), epochs=10, validation_split=0.2)

# Training the model with Adam optimizer and Sparse Categorical Cross-Entropy loss
model_adam_sparse_categorical = create_model(optimizer='adam', loss='sparse_categorical_crossentropy')
history_adam_sparse_categorical = model_adam_sparse_categorical.fit(X_train, Y_train, epochs=10, validation_split=0.2)

# Training the model with RMSprop optimizer and Categorical Cross-Entropy loss
model_rmsprop_categorical = create_model(optimizer='rmsprop', loss='categorical_crossentropy')
history_rmsprop_categorical = model_rmsprop_categorical.fit(X_train, tf.keras.utils.to_categorical(Y_train), epochs=10, validation_split=0.2)

# Training the model with RMSprop optimizer and Sparse Categorical Cross-Entropy loss
model_rmsprop_sparse_categorical = create_model(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
history_rmsprop_sparse_categorical = model_rmsprop_sparse_categorical.fit(X_train, Y_train, epochs=10, validation_split=0.2)

# Training the model with SGD optimizer and Categorical Cross-Entropy loss
model_sgd_categorical = create_model(optimizer='sgd', loss='categorical_crossentropy')
history_sgd_categorical = model_sgd_categorical.fit(X_train, tf.keras.utils.to_categorical(Y_train), epochs=10, validation_split=0.2)

# Training the model with SGD optimizer and Sparse Categorical Cross-Entropy loss
model_sgd_sparse_categorical = create_model(optimizer='sgd', loss='sparse_categorical_crossentropy')
history_sgd_sparse_categorical = model_sgd_sparse_categorical.fit(X_train, Y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 37s 29ms/step - loss: 1.6098 - accuracy: 0.4124 - val_loss: 1.3850 - val_accuracy: 0.5100
# Epoch 2/10
# 1250/1250 [==============================] - 37s 30ms/step - loss: 1.2693 - accuracy: 0.5486 - val_loss: 1.1905 - val_accuracy: 0.5792
# Epoch 3/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.1163 - accuracy: 0.6056 - val_loss: 1.0690 - val_accuracy: 0.6270
# Epoch 4/10
# 1250/1250 [==============================] - 34s 28ms/step - loss: 1.0241 - accuracy: 0.6399 - val_loss: 1.0651 - val_accuracy: 0.6308
# Epoch 5/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.9409 - accuracy: 0.6705 - val_loss: 0.9978 - val_accuracy: 0.6522
# Epoch 6/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.8808 - accuracy: 0.6906 - val_loss: 0.9467 - val_accuracy: 0.6731
# Epoch 7/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.8285 - accuracy: 0.7099 - val_loss: 0.9585 - val_accuracy: 0.6699
# Epoch 8/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.7830 - accuracy: 0.7229 - val_loss: 0.9425 - val_accuracy: 0.6732
# Epoch 9/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.7427 - accuracy: 0.7392 - val_loss: 0.9681 - val_accuracy: 0.6720
# Epoch 10/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.7057 - accuracy: 0.7533 - val_loss: 0.9152 - val_accuracy: 0.6867
# Epoch 1/10
# 1250/1250 [==============================] - 36s 28ms/step - loss: 1.6769 - accuracy: 0.3862 - val_loss: 1.4503 - val_accuracy: 0.4751
# Epoch 2/10
# 1250/1250 [==============================] - 34s 27ms/step - loss: 1.3217 - accuracy: 0.5264 - val_loss: 1.3015 - val_accuracy: 0.5293
# Epoch 3/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.1843 - accuracy: 0.5778 - val_loss: 1.1737 - val_accuracy: 0.5826
# Epoch 4/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.0889 - accuracy: 0.6136 - val_loss: 1.1037 - val_accuracy: 0.6169
# Epoch 5/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.0114 - accuracy: 0.6421 - val_loss: 1.0453 - val_accuracy: 0.6311
# Epoch 6/10
# 1250/1250 [==============================] - 34s 27ms/step - loss: 0.9570 - accuracy: 0.6640 - val_loss: 0.9970 - val_accuracy: 0.6546
# Epoch 7/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.9078 - accuracy: 0.6816 - val_loss: 1.0131 - val_accuracy: 0.6457
# Epoch 8/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.8612 - accuracy: 0.6984 - val_loss: 1.0077 - val_accuracy: 0.6514
# Epoch 9/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.8286 - accuracy: 0.7071 - val_loss: 1.0076 - val_accuracy: 0.6564
# Epoch 10/10
# 1250/1250 [==============================] - 34s 27ms/step - loss: 0.7940 - accuracy: 0.7207 - val_loss: 0.9877 - val_accuracy: 0.6696
# Epoch 1/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.6646 - accuracy: 0.3943 - val_loss: 1.3712 - val_accuracy: 0.5134
# Epoch 2/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.3014 - accuracy: 0.5347 - val_loss: 1.2299 - val_accuracy: 0.5658
# Epoch 3/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.1436 - accuracy: 0.5958 - val_loss: 1.1669 - val_accuracy: 0.5869
# Epoch 4/10
# 1250/1250 [==============================] - 34s 28ms/step - loss: 1.0320 - accuracy: 0.6385 - val_loss: 1.1253 - val_accuracy: 0.6024
# Epoch 5/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.9476 - accuracy: 0.6678 - val_loss: 0.9865 - val_accuracy: 0.6591
# Epoch 6/10
# 1250/1250 [==============================] - 36s 28ms/step - loss: 0.8810 - accuracy: 0.6918 - val_loss: 0.9755 - val_accuracy: 0.6613
# Epoch 7/10
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.8247 - accuracy: 0.7132 - val_loss: 0.9708 - val_accuracy: 0.6783
# Epoch 8/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.7751 - accuracy: 0.7316 - val_loss: 0.9941 - val_accuracy: 0.6698
# Epoch 9/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.7311 - accuracy: 0.7461 - val_loss: 0.9680 - val_accuracy: 0.6856
# Epoch 10/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.6866 - accuracy: 0.7617 - val_loss: 0.9908 - val_accuracy: 0.6718
# Epoch 1/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.7084 - accuracy: 0.3784 - val_loss: 1.4912 - val_accuracy: 0.4712
# Epoch 2/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.3073 - accuracy: 0.5389 - val_loss: 1.1961 - val_accuracy: 0.5800
# Epoch 3/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.1390 - accuracy: 0.6015 - val_loss: 1.1002 - val_accuracy: 0.6156
# Epoch 4/10
# 1250/1250 [==============================] - 36s 28ms/step - loss: 1.0300 - accuracy: 0.6415 - val_loss: 1.0709 - val_accuracy: 0.6280
# Epoch 5/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.9451 - accuracy: 0.6708 - val_loss: 1.0460 - val_accuracy: 0.6352
# Epoch 6/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.8748 - accuracy: 0.6959 - val_loss: 0.9791 - val_accuracy: 0.6722
# Epoch 7/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.8177 - accuracy: 0.7140 - val_loss: 1.0047 - val_accuracy: 0.6570
# Epoch 8/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.7695 - accuracy: 0.7347 - val_loss: 1.0008 - val_accuracy: 0.6557
# Epoch 9/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 0.7223 - accuracy: 0.7485 - val_loss: 0.9369 - val_accuracy: 0.6888
# Epoch 10/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.6840 - accuracy: 0.7625 - val_loss: 1.0364 - val_accuracy: 0.6654
# Epoch 1/10
# 1250/1250 [==============================] - 37s 29ms/step - loss: 2.1001 - accuracy: 0.2238 - val_loss: 1.9242 - val_accuracy: 0.2822
# Epoch 2/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.7934 - accuracy: 0.3477 - val_loss: 1.6471 - val_accuracy: 0.4068
# Epoch 3/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.5953 - accuracy: 0.4223 - val_loss: 1.5047 - val_accuracy: 0.4568
# Epoch 4/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.4759 - accuracy: 0.4697 - val_loss: 1.4405 - val_accuracy: 0.4768
# Epoch 5/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.3937 - accuracy: 0.4974 - val_loss: 1.3577 - val_accuracy: 0.5191
# Epoch 6/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.3298 - accuracy: 0.5243 - val_loss: 1.3291 - val_accuracy: 0.5227
# Epoch 7/10
# 1250/1250 [==============================] - 37s 30ms/step - loss: 1.2715 - accuracy: 0.5481 - val_loss: 1.2534 - val_accuracy: 0.5492
# Epoch 8/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.2162 - accuracy: 0.5693 - val_loss: 1.2373 - val_accuracy: 0.5678
# Epoch 9/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.1705 - accuracy: 0.5868 - val_loss: 1.1760 - val_accuracy: 0.5901
# Epoch 10/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.1220 - accuracy: 0.6051 - val_loss: 1.2253 - val_accuracy: 0.5600
# Epoch 1/10
# 1250/1250 [==============================] - 37s 29ms/step - loss: 2.1301 - accuracy: 0.2160 - val_loss: 1.9786 - val_accuracy: 0.2810
# Epoch 2/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.7935 - accuracy: 0.3516 - val_loss: 1.7048 - val_accuracy: 0.3835
# Epoch 3/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.6114 - accuracy: 0.4152 - val_loss: 1.5438 - val_accuracy: 0.4309
# Epoch 4/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.4912 - accuracy: 0.4598 - val_loss: 1.4425 - val_accuracy: 0.4871
# Epoch 5/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.4077 - accuracy: 0.4939 - val_loss: 1.3683 - val_accuracy: 0.5148
# Epoch 6/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.3332 - accuracy: 0.5256 - val_loss: 1.3124 - val_accuracy: 0.5341
# Epoch 7/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.2754 - accuracy: 0.5422 - val_loss: 1.2785 - val_accuracy: 0.5470
# Epoch 8/10
# 1250/1250 [==============================] - 36s 29ms/step - loss: 1.2219 - accuracy: 0.5660 - val_loss: 1.2859 - val_accuracy: 0.5513
# Epoch 9/10
# 1250/1250 [==============================] - 36s 28ms/step - loss: 1.1743 - accuracy: 0.5864 - val_loss: 1.1958 - val_accuracy: 0.5747
# Epoch 10/10
# 1250/1250 [==============================] - 35s 28ms/step - loss: 1.1290 - accuracy: 0.6017 - val_loss: 1.1598 - val_accuracy: 0.5864

# %%
#Training history plot for each model
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(history_adam_categorical.history['accuracy'], 'o-', label='Adam + Categorical Cross-Entropy')
plt.plot(history_adam_sparse_categorical.history['accuracy'], 'o-', label='Adam + Sparse Categorical Cross-Entropy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(2, 2, 2)
plt.plot(history_rmsprop_categorical.history['accuracy'], 'o-', label='RMSprop + Categorical Cross-Entropy')
plt.plot(history_rmsprop_sparse_categorical.history['accuracy'], 'o-', label='RMSprop + Sparse Categorical Cross-Entropy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(2, 2, 3)
plt.plot(history_sgd_categorical.history['accuracy'], 'o-', label='SGD + Categorical Cross-Entropy')
plt.plot(history_sgd_sparse_categorical.history['accuracy'], 'o-', label='SGD + Sparse Categorical Cross-Entropy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(2, 2, 4)
plt.plot(history_sgd_categorical.history['loss'], 'o-', label='SGD + Categorical Cross-Entropy')
plt.plot(history_sgd_sparse_categorical.history['loss'], 'o-', label='SGD + Sparse Categorical Cross-Entropy')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
# Function to plot images and predictions
def plot_images_with_predictions(images, true_labels, predictions, class_names, rows=5, cols=5):
    plt.figure(figsize=(20, 2 * rows))
    for i in range(rows * cols):
        plt.subplot(rows, 2 * cols, 2 * i + 1)
        plt.imshow(images[i])
        plt.xticks([])
        plt.yticks([])
        plt.ylabel(class_names[true_labels[i][0]])
        if true_labels[i][0] == np.argmax(predictions[i]):
            plt.xlabel(class_names[np.argmax(predictions[i])], color='g')
        else:
            plt.xlabel(class_names[np.argmax(predictions[i])], color='r')

        plt.subplot(rows, 2 * cols, 2 * i + 2)
        plt.bar(range(10), predictions[i])
        plt.yticks([])
        plt.xticks(range(0, 10))
        plt.ylim([0, 1])
        plt.xlim([0, 10])

# Ploting images and predictions for Adam + Categorical Cross-Entropy
predictions_adam_categorical = model_adam_categorical.predict(X_test)
plot_images_with_predictions(X_test, Y_test, predictions_adam_categorical, class_names)

# Ploting images and predictions for Adam + Sparse Categorical Cross-Entropy
predictions_adam_sparse_categorical = model_adam_sparse_categorical.predict(X_test)
plot_images_with_predictions(X_test, Y_test, predictions_adam_sparse_categorical, class_names)

# Ploting images and predictions for RMSprop + Categorical Cross-Entropy
predictions_rmsprop_categorical = model_rmsprop_categorical.predict(X_test)
plot_images_with_predictions(X_test, Y_test, predictions_rmsprop_categorical, class_names)

# Ploting images and predictions for RMSprop + Sparse Categorical Cross-Entropy
predictions_rmsprop_sparse_categorical = model_rmsprop_sparse_categorical.predict(X_test)
plot_images_with_predictions(X_test, Y_test, predictions_rmsprop_sparse_categorical, class_names)

# Ploting images and predictions for SGD + Categorical Cross-Entropy
predictions_sgd_categorical = model_sgd_categorical.predict(X_test)
plot_images_with_predictions(X_test, Y_test, predictions_sgd_categorical, class_names)

# Ploting images and predictions for SGD + Sparse Categorical Cross-Entropy
predictions_sgd_sparse_categorical = model_sgd_sparse_categorical.predict(X_test)
plot_images_with_predictions(X_test, Y_test, predictions_sgd_sparse_categorical, class_names)

plt.show()
# Out:
# 313/313 [==============================] - 3s 10ms/step
# 313/313 [==============================] - 2s 8ms/step
# 313/313 [==============================] - 3s 8ms/step
# 313/313 [==============================] - 3s 9ms/step
# 313/313 [==============================] - 3s 8ms/step
# 313/313 [==============================] - 3s 8ms/step
